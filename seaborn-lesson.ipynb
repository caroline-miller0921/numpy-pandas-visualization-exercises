# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Seaborn Highlights

# %% [markdown]
# - Intregrated with pandas
# - High level interface to plot data
# - Additional functionality, better defaults
# - Less code than matplotlib
# - All of the functionality is accessible at the top level.

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### Import statements

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# Seaborn API Reference
# https://seaborn.pydata.org/api.html#

# %% [markdown]
# ### Different type of plots in Seaborn
#
# ![seaborn_functions.png](attachment:seaborn_functions.png)
#
#  - source: https://seaborn.pydata.org/tutorial/function_overview.html

# %%
# Option 1 : Load directly from sns dataset using load_dataset
mpg = sns.load_dataset('mpg')

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# look for all datasets available in seaborn
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### **Relational Plots**

# %%
mpg.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
mpg.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# Let's make a scatter plot the way we learned before, with matplotlib:

# %%
# scatterplot in matplotlib
plt.scatter(mpg.horsepower, mpg.mpg)
plt.title('Miles Per Gallon by Horsepower')
plt.xlabel('Horsepower')
plt.ylabel('Miles Per Gallon')
# Out:
# Text(0, 0.5, 'Miles Per Gallon')

# %% [markdown]
# Now let's use one using seaborn's relplot

# %%
# Explore relationship between total_bill and tip using relplot
# instead of two series,
# Specify your data
# specify the strings that represent your x and y
sns.relplot(data=mpg, x='horsepower', y='mpg')
plt.title('Miles Per Gallon by Horsepower')
plt.xlabel('Horsepower')
plt.ylabel('Miles Per Gallon')
plt.show()

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### Extra dimension: Hue

# %%
mpg.origin.value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
sns.relplot(data=mpg, x='horsepower', y='mpg', hue='origin')
plt.show()

# %%
sns.relplot(data=mpg, x='horsepower', y='mpg', hue='cylinders')
plt.show()

# %%
# getting the axis level version

sns.scatterplot(data=mpg, x='horsepower', y='mpg', hue='origin')
plt.show()

# same thiung right? Maybe except that the origin is inside the plot

# %%
# relplot vs scatterplot

mpg.model_year.value_counts()
# Out:
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 70    29
# 79    29
# 80    29
# 81    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: model_year, dtype: int64

# %%
# Lets make columns by the decade
mpg['decade'] = mpg.model_year.apply(lambda x: str(x)[0]+'0\'s')
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name decade
# 0            70     usa  chevrolet chevelle malibu   70's
# 1            70     usa          buick skylark 320   70's
# 2            70     usa         plymouth satellite   70's
# 3            70     usa              amc rebel sst   70's
# 4            70     usa                ford torino   70's
# ..          ...     ...                        ...    ...
# 393          82     usa            ford mustang gl   80's
# 394          82  europe                  vw pickup   80's
# 395          82     usa              dodge rampage   80's
# 396          82     usa                ford ranger   80's
# 397          82     usa                 chevy s-10   80's
#
# [398 rows x 10 columns]

# %%
sns.relplot(data=mpg, x='horsepower', y='mpg', hue='decade')
plt.show()
# we can see that cars in the 70s have more horsepower but lower mpg
# makes sense right?

# %%
sns.relplot(data=mpg, x='horsepower', y='mpg', hue='decade', col='origin')
plt.show()

# %%
# Takeaways:
# looks like higher HP = lower mpg
# the 70s have higher HP and lower mpg
# the usa appears tp be the largest producer of higher HP and 
# lower mpg

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### Extra Dimension: **Style**

# %%
sns.relplot(data=mpg, x='horsepower', y='mpg', hue='decade', style='origin')
plt.show()

# %%
# WHOA this is messy, probably not the best way to shpw this data

# %%
# Lineplot

# %%
sns.lineplot(data=mpg, x='horsepower', y='mpg')
plt.show()

# %%
sns.relplot(data=mpg, x='horsepower', y='mpg', kind='line')
plt.show()

# %%
sns.lineplot?

# %% [markdown]
# https://en.wikipedia.org/wiki/Bootstrapping_(statistics)

# %% [markdown]
# ### Small multiple (https://en.wikipedia.org/wiki/Small_multiple)
# - similar graphs or charts using the same scale and axes
# - easy to compare
#
#
# - Main idea: Pick a categorical features and create a chart for each category

# %%
# Facetgrid with lineplot

# %% [markdown]
# #### Key takeaways?
# - Tip amount generally increases with total_bill
# - Waiter works in evenings on Sun and sat
# - Waiter works during lunchtime on Thursday

# %% [markdown]
# #### Ways to add DF columns to the chart (add new dimensions to the chart)
#
# - hue
# - col - creates subplots
# - style

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### **Distribution Plots**

# %%
sns.displot?

# %%
sns.displot(data=mpg, x='horsepower', kde=True, rug=True)

# %%
sns.displot(data=mpg, x='horsepower', kde=True, rug=True, hue='origin',
           palette=['r', 'g', 'b'], multiple='stack', alpha=0.2);

# %%
sns.displot(data=mpg, x='horsepower', kde=True, rug=True, hue='origin',
           palette=['r', 'g', 'b'], multiple='stack', alpha=0.2, col='decade');

# %%
sns.histplot(data=mpg, x='horsepower')
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Count'>

# %%
# kde = probability of finding a observartions at particular 
# value of x.
# Smooth out version of histogram. 
# Estimating probabilty density function (PDF) 
# in a non-parametric way.

# %%
# histogram with hue and stacking

# %%
# use 'col' argument to create 'small multiples'

# %%
#histplot will return an axes level object

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### **Categorical Plots**

# %% [markdown]
# #### Boxplots

# %%
#  FacetGrid with 'col'

# %%
sns.catplot(data=mpg, x='decade', y='mpg', kind='box')

# %%
sns.catplot(data=mpg, x='decade', y='mpg')

# %%
sns.catplot(data=mpg, x='decade', y='mpg', kind='box',
            col='origin')

# %%
sns.violinplot(data=mpg, x='decade', y='mpg')
# Out:
# <AxesSubplot:xlabel='decade', ylabel='mpg'>

# %%
sns.swarmplot(data=mpg, x='decade', y='mpg')
# Out:
# <AxesSubplot:xlabel='decade', ylabel='mpg'>

# %%
sns.dogplot()

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ### **Subplots**

# %%
tips = sns.load_dataset('tips')

# %%
plt.figure(figsize=(12, 10))
plt.suptitle('Boxplots with Seaborn')

plt.subplot(221)
sns.boxplot(data=tips, y='tip')
plt.title('A "typical" boxplot')

plt.subplot(222)
sns.boxplot(data=tips, x='tip')
plt.title('Rotated 90$\degree$')

plt.subplot(223)
sns.boxplot(data=tips, y='tip', x='size')
plt.title('Providing an x and y value groups the data')

plt.subplot(224)
sns.boxplot(data=tips, y='time', x='tip', hue='smoker')
plt.title('You can also use other kwargs, like hue')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# #### Pairplot

# %%
sns.pairplot(mpg)

# %%
sns.pairplot(mpg, corner=True)
# corner means the unique plots only appear

# %%
# pairplot is great for birdseye of your data

# %% [markdown]
# #### Jointplot

# %%
sns.jointplot(data=mpg, x='horsepower', y='mpg', kind='reg')

# %% [markdown]
# #### Heatmap

# %%
sns.heatmap(mpg.corr(),
           annot=True,
           cmap='coolwarm',
           vmax=1,
           vmin=-1,
           center=0,
           linewidth=1,
           linecolor='k',
           fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
# good for cross tabular information

# %%
mpg.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %% [markdown]
# Seaborn color palettes: https://seaborn.pydata.org/tutorial/color_palettes.html
# Check out this great post too: https://medium.com/@morganjonesartist/color-guide-to-seaborn-palettes-da849406d44f
